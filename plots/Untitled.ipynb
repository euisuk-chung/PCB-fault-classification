# %%
import matplotlib.pyplot as plt

# %%
a = [1, 2, 3, 4, 5]

b = [0.99, 0.88, 0.77, 0.85, 0.88]
c = [0.9, 0.8, 0.71, 0.83, 0.84]

# %%
plt.plot(b)
plt.plot(c)

# %%
list(range(10, ))
# Out:
# []

# %%
[1, 2] + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3860ff0fe467> in <module>
# ----> 1 [1, 2] + 1
#
# TypeError: can only concatenate list (not "int") to list
